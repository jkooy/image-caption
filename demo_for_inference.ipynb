# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from PIL import Image
image = Image.open('./example_pics/1.png')
plt.imshow(image)
! python sample.py --image './example_pics/1.png'
# Out:
# torch.Size([1, 3, 224, 224])
# a group of giraffes are standing in a zoo exhibit .

# %%
image = Image.open('./example_pics/2.jpg')
plt.imshow(image)
! python sample.py --image './example_pics/2.jpg'
# Out:
# torch.Size([1, 3, 224, 224])
# a group of people on horses playing baseball .

# %%
image = Image.open('./example_pics/3.jpg')
plt.imshow(image)
! python sample.py --image './example_pics/3.jpg'
# Out:
# torch.Size([1, 3, 224, 224])
# a man is sitting on a bench talking on a cell phone .

# %%
image = Image.open('./example_pics/4.jpg')
plt.imshow(image)
! python sample.py --image './example_pics/4.jpg'
# Out:
# torch.Size([1, 3, 224, 224])
# a stop sign with a street sign on top of it .

# %%
image = Image.open('./example_pics/5.jpg')
plt.imshow(image)
! python sample.py --image './example_pics/5.jpg'
# Out:
# torch.Size([1, 3, 224, 224])
# a parking meter on a city street with a building in the background .

# %%
image = Image.open('./example_pics/6.jpg')
plt.imshow(image)
! python sample.py --image './example_pics/6.jpg'
# Out:
# torch.Size([1, 3, 224, 224])
# a young girl is eating a hot dog .

# %%
image = Image.open('./example_pics/7.jpg')
plt.imshow(image)
! python sample.py --image './example_pics/7.jpg'
# Out:
# torch.Size([1, 3, 224, 224])
# a bathroom with a toilet , sink , and shower .
